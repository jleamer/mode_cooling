# %%
import numpy as np
import sympy as sym

# %%
α, β, nc, nT = sym.symbols('α, β, nc, nT')

# %%
s = (4 * α * β * nc + (α * β - 1) ** 2 * nT) / (α * β + 1) ** 2

# %%
s
# Out:
# (nT*(α*β - 1)**2 + 4*nc*α*β)/(α*β + 1)**2

# %%
sym.diff(s, α)
# Out:
# -2*β*(nT*(α*β - 1)**2 + 4*nc*α*β)/(α*β + 1)**3 + (2*nT*β*(α*β - 1) + 4*nc*β)/(α*β + 1)**2

# %%
temp = (4 * (α * β + 1) * β * nc + 2 * (α * β + 1) * (α * β - 1) * β * nT - 8 * α * β ** 2 * nc - 2 * (α * β -1) ** 2 * β * nT) / (α * β + 1) ** 3

# %%
temp
# Out:
# (-2*nT*β*(α*β - 1)**2 + nT*β*(α*β - 1)*(2*α*β + 2) - 8*nc*α*β**2 + nc*β*(4*α*β + 4))/(α*β + 1)**3

# %%
sym.solve(sym.diff(s, α), α)
# Out:
# [1/β]
